# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# URL for Titanic Dataset
url = "https://raw.githubusercontent.com/mwaskom/seaborn-data/master/titanic.csv"
df = pd.read_csv(url)

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df.shape
# Out:
# (891, 15)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    str
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    str
#  8   class        891 non-null    str
#  9   who          891 non-null    str
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    str
#  12  embark_town  889 non-null    str
#  13  alive        891 non-null    str
#  14  alone        891 non-null    bool
# dtypes: bool(2), float64(2), int64(4), str(7)
# memory usage: 116.9 KB

# %%
# Null Values in COlumns
df.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
df.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
df.mean(numeric_only=True)
# Out:
# survived       0.383838
# pclass         2.308642
# age           29.699118
# sibsp          0.523008
# parch          0.381594
# fare          32.204208
# adult_male     0.602694
# alone          0.602694
# dtype: float64

# %%
df.median(numeric_only=True)
# Out:
# survived       0.0000
# pclass         3.0000
# age           28.0000
# sibsp          0.0000
# parch          0.0000
# fare          14.4542
# adult_male     1.0000
# alone          1.0000
# dtype: float64

# %%
df.mode()
# Out:
#    survived  pclass   sex   age  sibsp  parch  fare embarked  class  who  \
# 0         0       3  male  24.0      0      0  8.05        S  Third  man
#
#    adult_male deck  embark_town alive  alone
# 0        True    C  Southampton    no   True

# %%
df.std(numeric_only=True)
# Out:
# survived       0.486592
# pclass         0.836071
# age           14.526497
# sibsp          1.102743
# parch          0.806057
# fare          49.693429
# adult_male     0.489615
# alone          0.489615
# dtype: float64

# %%
df.var(numeric_only=True)
# Out:
# survived         0.236772
# pclass           0.699015
# age            211.019125
# sibsp            1.216043
# parch            0.649728
# fare          2469.436846
# adult_male       0.239723
# alone            0.239723
# dtype: float64

# %%
print("Minimum Values = ")
print(df.min(numeric_only=True))

print("\nMaximum Values = ")
print(df.max(numeric_only=True))
# Out:
# Minimum Values =
# survived          0
# pclass            1
# age            0.42
# sibsp             0
# parch             0
# fare            0.0
# adult_male    False
# alone         False
# dtype: object
#
# Maximum Values =
# survived             1
# pclass               3
# age               80.0
# sibsp                8
# parch                6
# fare          512.3292
# adult_male        True
# alone             True
# dtype: object

# %%
df["fare"].describe()
# Out:
# count    891.000000
# mean      32.204208
# std       49.693429
# min        0.000000
# 25%        7.910400
# 50%       14.454200
# 75%       31.000000
# max      512.329200
# Name: fare, dtype: float64

# %%
plt.figure(figsize=(8,5))
sns.histplot(df["age"], bins=20, kde=True)
plt.title("Distribution of Age")
plt.xlabel("Age")
plt.ylabel("Frequency")
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.histplot(df["fare"], bins=20, kde=True)
plt.title("Distribution of Fare")
plt.xlabel("Fare")
plt.ylabel("Frequency")
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.countplot(x="sex", data=df)
plt.title("Gender Distribution")
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.countplot(x="class", data=df)
plt.title("Passenger Class Distribution")
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.countplot(x="survived", data=df)
plt.title("Survival Count")
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.boxplot(x=df["fare"])
plt.title("Box Plot of Fare")
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.boxplot(x=df["age"])
plt.title("Box Plot of Age")
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.scatterplot(x="age", y="fare", data=df)
plt.title("Age vs Fare")
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.countplot(x="sex", hue="survived", data=df)
plt.title("Survival Based on Gender")
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.countplot(x="class", hue="survived", data=df)
plt.title("Survival Based on Passenger Class")
plt.show()

# %%
correlation = df.corr(numeric_only=True)
correlation
# Out:
#             survived    pclass       age     sibsp     parch      fare  \
# survived    1.000000 -0.338481 -0.077221 -0.035322  0.081629  0.257307
# pclass     -0.338481  1.000000 -0.369226  0.083081  0.018443 -0.549500
# age        -0.077221 -0.369226  1.000000 -0.308247 -0.189119  0.096067
# sibsp      -0.035322  0.083081 -0.308247  1.000000  0.414838  0.159651
# parch       0.081629  0.018443 -0.189119  0.414838  1.000000  0.216225
# fare        0.257307 -0.549500  0.096067  0.159651  0.216225  1.000000
# adult_male -0.557080  0.094035  0.280328 -0.253586 -0.349943 -0.182024
# alone      -0.203367  0.135207  0.198270 -0.584471 -0.583398 -0.271832
#
#             adult_male     alone
# survived     -0.557080 -0.203367
# pclass        0.094035  0.135207
# age           0.280328  0.198270
# sibsp        -0.253586 -0.584471
# parch        -0.349943 -0.583398
# fare         -0.182024 -0.271832
# adult_male    1.000000  0.404744
# alone         0.404744  1.000000

# %%
plt.figure(figsize=(10,8))
sns.heatmap(correlation, annot=True, cmap="coolwarm", linewidths=0.5)
plt.title("Correlation Heatmap")
plt.show()

# %%
''' 
From the heatmap:

- **Survived and Fare (0.26):** Passengers who paid higher fares had a slightly higher chance of survival.
- **Survived and Pclass (-0.34):** Higher passenger class number (Third Class) is associated with lower survival, meaning first-class passengers had better survival chances.
- **Pclass and Fare (-0.55):** A strong negative correlation indicates that first-class passengers generally paid higher fares.
- **SibSp and Parch (0.41):** Passengers traveling with siblings/spouses were also likely to travel with parents or children.
- **Age and Fare (0.096):** Almost no correlation exists between age and ticket fare.

Overall, the heatmap shows that passenger class and fare had a greater influence on survival than age. 
'''
# Out:
# ' \nFrom the heatmap:\n\n- **Survived and Fare (0.26):** Passengers who paid higher fares had a slightly higher chance of survival.\n- **Survived and Pclass (-0.34):** Higher passenger class number (Third Class) is associated with lower survival, meaning first-class passengers had better survival chances.\n- **Pclass and Fare (-0.55):** A strong negative correlation indicates that first-class passengers generally paid higher fares.\n- **SibSp and Parch (0.41):** Passengers traveling with siblings/spouses were also likely to travel with parents or children.\n- **Age and Fare (0.096):** Almost no correlation exists between age and ticket fare.\n\nOverall, the heatmap shows that passenger class and fare had a greater influence on survival than age. \n'

# %%
sns.pairplot(df[['survived','age','fare','pclass']])
plt.show()
